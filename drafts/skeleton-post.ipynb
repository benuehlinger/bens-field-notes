# %% [raw]
# ---
# title: "Draft: Untitled analysis"
# description: "Copy this file to drafts/my-topic.ipynb and edit. Publish to posts/ when ready."
# date: 2026-06-05
# categories: [methodology]
# type: notebook
# jupyter: python3
# execute:
#   echo: true
#   warning: false
#   message: false
# ---

# %% [markdown]
# ## Draft notebook template
#
# 1. Copy: `cp drafts/skeleton-post.ipynb drafts/my-topic.ipynb`
# 2. Work in Jupyter: `jupyter lab drafts/my-topic.ipynb`
# 3. Preview: `quarto preview drafts/my-topic.ipynb`
# 4. Publish: move to `posts/YYYY-MM-DD-slug/index.ipynb`, update YAML, commit.
#
# See the live example: [ABS-EE From the Lake](../posts/2026-06-05-abs-ee-from-the-lake/index.ipynb).

# %%
import os
print("R2:", os.environ.get("R2_BASE_URL", "(set in .env.local for local renders)"))
